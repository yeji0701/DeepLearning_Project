# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Tue Feb 16 07:37:12 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    26W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.4 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# !tar -xvf /content/drive/MyDrive/darknet/cudnn/cudnn-10.1-linux-x64-v8.0.5.39.tar -C /usr/local/
# !cat /usr/local/cuda/include/cudnn_version.h | grep CUDNN_MAJOR -A 2
# Out:
# cuda/include/cudnn.h
# cuda/include/cudnn_adv_infer.h
# cuda/include/cudnn_adv_train.h
# cuda/include/cudnn_backend.h
# cuda/include/cudnn_cnn_infer.h
# cuda/include/cudnn_cnn_train.h
# cuda/include/cudnn_ops_infer.h
# cuda/include/cudnn_ops_train.h
# cuda/include/cudnn_version.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.8
# cuda/lib64/libcudnn.so.8.0.5
# cuda/lib64/libcudnn_adv_infer.so
# cuda/lib64/libcudnn_adv_infer.so.8
# cuda/lib64/libcudnn_adv_infer.so.8.0.5
# cuda/lib64/libcudnn_adv_train.so
# cuda/lib64/libcudnn_adv_train.so.8
# cuda/lib64/libcudnn_adv_train.so.8.0.5
# cuda/lib64/libcudnn_cnn_infer.so
# cuda/lib64/libcudnn_cnn_infer.so.8
# cuda/lib64/libcudnn_cnn_infer.so.8.0.5
# cuda/lib64/libcudnn_cnn_train.so
# cuda/lib64/libcudnn_cnn_train.so.8
# cuda/lib64/libcudnn_cnn_train.so.8.0.5
# cuda/lib64/libcudnn_ops_infer.so
# cuda/lib64/libcudnn_ops_infer.so.8
# cuda/lib64/libcudnn_ops_infer.so.8.0.5
# ...

# %%
# %cd /content/drive/MyDrive/yolov5/
# Out:
# /content/drive/MyDrive/yolov5

# %%
# !pip install -U -r ./requirements.txt # install dependencies
# Out:
# Requirement already up-to-date: Cython in /usr/local/lib/python3.6/dist-packages (from -r ./requirements.txt (line 4)) (0.29.21)
# Requirement already up-to-date: matplotlib>=3.2.2 in /usr/local/lib/python3.6/dist-packages (from -r ./requirements.txt (line 5)) (3.3.4)
# Requirement already up-to-date: numpy>=1.18.5 in /usr/local/lib/python3.6/dist-packages (from -r ./requirements.txt (line 6)) (1.19.5)
# Requirement already up-to-date: opencv-python>=4.1.2 in /usr/local/lib/python3.6/dist-packages (from -r ./requirements.txt (line 7)) (4.5.1.48)
# Requirement already up-to-date: Pillow in /usr/local/lib/python3.6/dist-packages (from -r ./requirements.txt (line 8)) (8.1.0)
# Requirement already up-to-date: PyYAML>=5.3.1 in /usr/local/lib/python3.6/dist-packages (from -r ./requirements.txt (line 9)) (5.4.1)
# Requirement already up-to-date: scipy>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from -r ./requirements.txt (line 10)) (1.5.4)
# ...

# %%
import torch
from IPython.display import Image  # for displaying images
from utils.google_utils import gdrive_download  # for downloading models/datasets

print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# torch 1.7.1 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
# %ls
# Out:
# data/       hubconf.py  __pycache__/      scoreboard.xlsx  utils/
# data.yaml   LICENSE     README.md         test.py          wandb/
# detect.py   models/     requirements.txt  train.py         weights/
# Dockerfile  project/    runs/             tutorial.ipynb

# %%
# %cat data.yaml
# Out:
# # train and val data as 1) directory: path/images/, 2) file: path/images.txt, or 3) list: [path1/images/, path2/images/]
# train: ./project/train
# val: ./project/val
#
# # number of classes
# nc: 1
#
# # class names
# names: ['rider']

# %%
pip install wandb
# Out:
# ...
#      |████████████████████████████████| 2.0MB 8.3MB/s
# ...
#      |████████████████████████████████| 133kB 48.5MB/s
# ...
#      |████████████████████████████████| 102kB 11.7MB/s
# ...
#      |████████████████████████████████| 163kB 39.6MB/s
# ...
#      |████████████████████████████████| 71kB 10.0MB/s
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-cp36-none-any.whl size=6490 sha256=063d214a0c5c3d42bde4c9aeb9f958cfc6bc6a4d1ecfc7ad4e890357f11bce95
#   Stored in directory: /root/.cache/pip/wheels/68/39/1a/5e402bdfdf004af1786c8b853fd92f8c4a04f22aad179654d1
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-cp36-none-any.whl size=8785 sha256=d40be017ee1266f0998c9302494e88d77ecd49959fdbff07b9faca513b5455ad
#   Stored in directory: /root/.cache/pip/wheels/0b/04/79/c3b0c3a0266a3cb4376da31e5bfe8bba0c489246968a68e843
# Successfully built subprocess32 pathtools
# ...

# %%
# %ls
# Out:
# data/       hubconf.py  __pycache__/      scoreboard.xlsx  utils/
# data.yaml   LICENSE     README.md         test.py          wandb/
# detect.py   models/     requirements.txt  train.py         weights/
# Dockerfile  project/    runs/             tutorial.ipynb

# %%
# !LD_LIBRARY_PATH=/usr/local/cuda/lib64/ python3 train.py --epoch 1000 --batch-size 16 --data data.yaml --weights ./weights/yolov5x.pt --cfg yolov5x.yaml --name final_35011
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 1/1 [00:00<00:00,  3.28it/s]
#
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     11/999     14.1G   0.09054   0.03077         0    0.1213         6       640: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 1/1 [00:00<00:00,  3.32it/s]
#
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     12/999     14.1G    0.1005   0.03932         0    0.1398        12       640: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 1/1 [00:00<00:00,  3.45it/s]
#
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
# ...

# %%
# !LD_LIBRARY_PATH=/usr/local/cuda/lib64/ python3 detect.py --source ./project/test_videos/02.mp4 \
--weights ./runs/train/final_35011/weights/best.pt --conf-thres 0.7
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.7, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='./project/test_videos/02.mp4', update=False, view_img=False, weights=['./runs/train/final_35011/weights/best.pt'])
# YOLOv5 v4.0-77-g3e560e2 torch 1.7.1 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87198694 parameters, 0 gradients, 217.1 GFLOPS
# video 1/1 (1/164) /content/drive/My Drive/yolov5/project/test_videos/02.mp4: 384x640 1 rider, Done. (0.034s)
# video 1/1 (2/164) /content/drive/My Drive/yolov5/project/test_videos/02.mp4: 384x640 1 rider, Done. (0.032s)
# video 1/1 (3/164) /content/drive/My Drive/yolov5/project/test_videos/02.mp4: 384x640 1 rider, Done. (0.032s)
# video 1/1 (4/164) /content/drive/My Drive/yolov5/project/test_videos/02.mp4: 384x640 1 rider, Done. (0.032s)
# ...

# %%
# !LD_LIBRARY_PATH=/usr/local/cuda/lib64/ python3 detect.py --source ./project/test_videos/03.mp4 \
--weights ./runs/train/final_35011/weights/best.pt --conf-thres 0.7
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.7, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='./project/test_videos/03.mp4', update=False, view_img=False, weights=['./runs/train/final_35011/weights/best.pt'])
# YOLOv5 v4.0-77-g3e560e2 torch 1.7.1 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87198694 parameters, 0 gradients, 217.1 GFLOPS
# video 1/1 (1/172) /content/drive/My Drive/yolov5/project/test_videos/03.mp4: 384x640 Done. (0.032s)
# video 1/1 (2/172) /content/drive/My Drive/yolov5/project/test_videos/03.mp4: 384x640 Done. (0.031s)
# video 1/1 (3/172) /content/drive/My Drive/yolov5/project/test_videos/03.mp4: 384x640 Done. (0.031s)
# video 1/1 (4/172) /content/drive/My Drive/yolov5/project/test_videos/03.mp4: 384x640 Done. (0.031s)
# ...

# %%
# %ls
# Out:
# data/       hubconf.py  __pycache__/      scoreboard.xlsx  utils/
# data.yaml   LICENSE     README.md         test.py          wandb/
# detect.py   models/     requirements.txt  train.py         weights/
# Dockerfile  project/    runs/             tutorial.ipynb

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/yolov5'

# %%
# !LD_LIBRARY_PATH=/usr/local/cuda/lib64/ python3 detect.py --source ./project/test_videos/30009_outdoor.mp4 \
--weights ./runs/train/final_30009_2/weights/best.pt --conf-thres 0.7 --agnostic-nms
# Out:
# Namespace(agnostic_nms=True, augment=False, classes=None, conf_thres=0.7, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='./project/test_videos/30009_outdoor.mp4', update=False, view_img=False, weights=['./runs/train/final_30009_2/weights/best.pt'])
# YOLOv5 v4.0-77-g3e560e2 torch 1.7.1 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87198694 parameters, 0 gradients, 217.1 GFLOPS
# video 1/1 (1/675) /content/drive/My Drive/yolov5/project/test_videos/30009_outdoor.mp4: 384x640 1 pedestrian, Done. (0.037s)
# video 1/1 (2/675) /content/drive/My Drive/yolov5/project/test_videos/30009_outdoor.mp4: 384x640 1 pedestrian, Done. (0.032s)
# video 1/1 (3/675) /content/drive/My Drive/yolov5/project/test_videos/30009_outdoor.mp4: 384x640 1 pedestrian, Done. (0.032s)
# ...

# %%
# !LD_LIBRARY_PATH=/usr/local/cuda/lib64/ python3 detect.py --source ./project/test_videos/06277_indoor.mp4 \
--weights ./runs/train/final_06277/weights/best.pt --conf-thres 0.6 --agnostic-nms
# Out:
# Namespace(agnostic_nms=True, augment=False, classes=None, conf_thres=0.6, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='./project/test_videos/06277_indoor.mp4', update=False, view_img=False, weights=['./runs/train/final_06277/weights/best.pt'])
# YOLOv5 v4.0-77-g3e560e2 torch 1.7.1 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87198694 parameters, 0 gradients, 217.1 GFLOPS
# video 1/1 (1/430) /content/drive/My Drive/yolov5/project/test_videos/06277_indoor.mp4: 384x640 Done. (0.036s)
# video 1/1 (2/430) /content/drive/My Drive/yolov5/project/test_videos/06277_indoor.mp4: 384x640 Done. (0.034s)
# video 1/1 (3/430) /content/drive/My Drive/yolov5/project/test_videos/06277_indoor.mp4: 384x640 Done. (0.031s)
# video 1/1 (4/430) /content/drive/My Drive/yolov5/project/test_videos/06277_indoor.mp4: 384x640 Done. (0.031s)
# ...
