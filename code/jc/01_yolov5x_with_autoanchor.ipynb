# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sun Feb 14 09:38:26 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.4 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# !tar -xvf /content/drive/MyDrive/darknet/cudnn/cudnn-10.1-linux-x64-v8.0.5.39.tar -C /usr/local/
# !cat /usr/local/cuda/include/cudnn_version.h | grep CUDNN_MAJOR -A 2
# Out:
# cuda/include/cudnn.h
# cuda/include/cudnn_adv_infer.h
# cuda/include/cudnn_adv_train.h
# cuda/include/cudnn_backend.h
# cuda/include/cudnn_cnn_infer.h
# cuda/include/cudnn_cnn_train.h
# cuda/include/cudnn_ops_infer.h
# cuda/include/cudnn_ops_train.h
# cuda/include/cudnn_version.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.8
# cuda/lib64/libcudnn.so.8.0.5
# cuda/lib64/libcudnn_adv_infer.so
# cuda/lib64/libcudnn_adv_infer.so.8
# cuda/lib64/libcudnn_adv_infer.so.8.0.5
# cuda/lib64/libcudnn_adv_train.so
# cuda/lib64/libcudnn_adv_train.so.8
# cuda/lib64/libcudnn_adv_train.so.8.0.5
# cuda/lib64/libcudnn_cnn_infer.so
# cuda/lib64/libcudnn_cnn_infer.so.8
# cuda/lib64/libcudnn_cnn_infer.so.8.0.5
# cuda/lib64/libcudnn_cnn_train.so
# cuda/lib64/libcudnn_cnn_train.so.8
# cuda/lib64/libcudnn_cnn_train.so.8.0.5
# cuda/lib64/libcudnn_ops_infer.so
# cuda/lib64/libcudnn_ops_infer.so.8
# cuda/lib64/libcudnn_ops_infer.so.8.0.5
# ...

# %%
# %cd /content/drive/MyDrive/yolov5/
# Out:
# /content/drive/MyDrive/yolov5

# %%
# !pip install -U -r ./requirements.txt # install dependencies
# Out:
# Requirement already up-to-date: Cython in /usr/local/lib/python3.6/dist-packages (from -r ./requirements.txt (line 4)) (0.29.21)
# ...
#      |████████████████████████████████| 11.5MB 15.2MB/s
# Requirement already up-to-date: numpy>=1.18.5 in /usr/local/lib/python3.6/dist-packages (from -r ./requirements.txt (line 6)) (1.19.5)
# ...
#      |████████████████████████████████| 50.4MB 121kB/s
# ...
#      |████████████████████████████████| 2.2MB 47.3MB/s
# ...
#      |████████████████████████████████| 645kB 51.4MB/s
# ...
#      |████████████████████████████████| 25.9MB 69.1MB/s
# Requirement already up-to-date: tensorboard>=2.2 in /usr/local/lib/python3.6/dist-packages (from -r ./requirements.txt (line 11)) (2.4.1)
# ...
#      |████████████████████████████████| 776.8MB 18kB/s
# ...
#      |████████████████████████████████| 12.8MB 47.0MB/s
# ...
#      |████████████████████████████████| 81kB 11.3MB/s
# ...

# %%
import torch
from IPython.display import Image  # for displaying images
from utils.google_utils import gdrive_download  # for downloading models/datasets

print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# torch 1.7.1 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', major=7, minor=0, total_memory=16160MB, multi_processor_count=80)

# %%
# %ls
# Out:
#  data/        models/              runs/      tutorial.ipynb   yolov5s.pt
#  detect.py   'path.ipynb의 사본'   test/      utils/           yolov5x.pt
#  Dockerfile   __pycache__/         test.py    wandb/
#  hubconf.py   README.md            track.py   weights/
#  LICENSE      requirements.txt     train.py   yolov5m.pt

# %%
# %cat ./data/custom.yaml
# Out:
# # train and val data as 1) directory: path/images/, 2) file: path/images.txt, or 3) list: [path1/images/, path2/images/]
# train: /content/drive/MyDrive/project/frames/train
# val: /content/drive/MyDrive/project/frames/val
#
# # number of classes
# nc: 1
#
# # class names
# names: ['person']

# %%
pip install wandb

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# !LD_LIBRARY_PATH=/usr/local/cuda/lib64/ python3 train.py --epoch 800 --batch-size 16 \
--data ./data/custom.yaml --weights ./weights/yolov5x.pt --cfg yolov5x.yaml \
--name xlarge_with_aug_anchor
# Out:
# github: ⚠️ WARNING: code is out of date by 7 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# YOLOv5 v4.0-70-gc32b0af torch 1.7.1 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='./models/yolov5x.yaml', data='./data/custom.yaml', device='', epochs=800, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], linear_lr=False, local_rank=-1, log_artifacts=False, log_imgs=16, multi_scale=False, name='xlarge_with_aug_anchor', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/xlarge_with_aug_anchor2', single_cls=False, sync_bn=False, total_batch_size=16, weights='./weights/yolov5x.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...

# %%
# !LD_LIBRARY_PATH=/usr/local/cuda/lib64/ python3 detect.py --source ../../project/01.mp4 --weights ./runs/train/xlarge_with_aug_anchor2/weights/best.pt --conf-thres 0.4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='../../project/01.mp4', update=False, view_img=False, weights=['./runs/train/xlarge_with_aug_anchor2/weights/best.pt'])
# YOLOv5 v4.0-70-gc32b0af torch 1.7.1 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87198694 parameters, 0 gradients, 217.1 GFLOPS
# video 1/1 (1/100) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/01.mp4: 384x640 1 person, Done. (0.020s)
# video 1/1 (2/100) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/01.mp4: 384x640 1 person, Done. (0.019s)
# video 1/1 (3/100) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/01.mp4: 384x640 1 person, Done. (0.019s)
# ...

# %%
# !LD_LIBRARY_PATH=/usr/local/cuda/lib64/ python3 detect.py --source ../../project/02.mp4 --weights ./runs/train/xlarge_with_aug_anchor2/weights/best.pt --conf-thres 0.4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='../../project/02.mp4', update=False, view_img=False, weights=['./runs/train/xlarge_with_aug_anchor2/weights/best.pt'])
# YOLOv5 v4.0-70-gc32b0af torch 1.7.1 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87198694 parameters, 0 gradients, 217.1 GFLOPS
# video 1/1 (1/724) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/02.mp4: 384x640 Done. (0.019s)
# video 1/1 (2/724) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/02.mp4: 384x640 Done. (0.017s)
# video 1/1 (3/724) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/02.mp4: 384x640 Done. (0.017s)
# video 1/1 (4/724) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/02.mp4: 384x640 Done. (0.017s)
# ...

# %%
# !LD_LIBRARY_PATH=/usr/local/cuda/lib64/ python3 detect.py --source ../../project/03.mp4 --weights ./runs/train/xlarge_with_aug_anchor2/weights/best.pt --conf-thres 0.4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='../../project/03.mp4', update=False, view_img=False, weights=['./runs/train/xlarge_with_aug_anchor2/weights/best.pt'])
# YOLOv5 v4.0-70-gc32b0af torch 1.7.1 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87198694 parameters, 0 gradients, 217.1 GFLOPS
# video 1/1 (1/350) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/03.mp4: 384x640 Done. (0.019s)
# video 1/1 (2/350) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/03.mp4: 384x640 Done. (0.018s)
# video 1/1 (3/350) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/03.mp4: 384x640 Done. (0.018s)
# video 1/1 (4/350) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/03.mp4: 384x640 Done. (0.017s)
# ...

# %%
# !LD_LIBRARY_PATH=/usr/local/cuda/lib64/ python3 detect.py --source ../../project/04.mp4 --weights ./runs/train/xlarge_with_aug_anchor2/weights/best.pt --conf-thres 0.4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='../../project/04.mp4', update=False, view_img=False, weights=['./runs/train/xlarge_with_aug_anchor2/weights/best.pt'])
# YOLOv5 v4.0-70-gc32b0af torch 1.7.1 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87198694 parameters, 0 gradients, 217.1 GFLOPS
# video 1/1 (1/768) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/04.mp4: 384x640 Done. (0.020s)
# video 1/1 (2/768) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/04.mp4: 384x640 Done. (0.018s)
# video 1/1 (3/768) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/04.mp4: 384x640 Done. (0.017s)
# video 1/1 (4/768) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/04.mp4: 384x640 Done. (0.018s)
# ...

# %%
# !LD_LIBRARY_PATH=/usr/local/cuda/lib64/ python3 detect.py --source ../../project/05.mp4 \
--weights ./runs/train/xlarge_with_aug_anchor2/weights/best.pt --conf-thres 0.4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='../../project/05.mp4', update=False, view_img=False, weights=['./runs/train/xlarge_with_aug_anchor2/weights/best.pt'])
# YOLOv5 v4.0-70-gc32b0af torch 1.7.1 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87198694 parameters, 0 gradients, 217.1 GFLOPS
# video 1/1 (1/197) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/05.mp4: 384x640 Done. (0.018s)
# video 1/1 (2/197) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/05.mp4: 384x640 Done. (0.017s)
# video 1/1 (3/197) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/05.mp4: 384x640 Done. (0.017s)
# video 1/1 (4/197) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/05.mp4: 384x640 Done. (0.017s)
# ...

# %%
# !LD_LIBRARY_PATH=/usr/local/cuda/lib64/ python3 detect.py
--source ../../project/indoor_01.mp4 \
--weights ./runs/train/xlarge_with_aug_anchor2/weights/best.pt
--conf-thres 0.4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='../../project/indoor_01.mp4', update=False, view_img=False, weights=['./runs/train/xlarge_with_aug_anchor2/weights/best.pt'])
# YOLOv5 v4.0-70-gc32b0af torch 1.7.1 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87198694 parameters, 0 gradients, 217.1 GFLOPS
# video 1/1 (1/1860) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/indoor_01.mp4: 384x640 1 person, Done. (0.020s)
# video 1/1 (2/1860) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/indoor_01.mp4: 384x640 1 person, Done. (0.019s)
# video 1/1 (3/1860) /content/drive/My Drive/Yolov5_DeepSort_Pytorch/yolov5/../../project/indoor_01.mp4: 384x640 1 person, Done. (0.019s)
# ...

# %%
from utils.autoanchor import *
_ = kmean_anchors(path='./data.yaml', n=9, img_size=640, thr=4.0, gen=1000, verbose=True)
# Out:
# Scanning 'project/train.cache' for images and labels... 56 found, 0 missing, 0 empty, 0 corrupted: 100%|██████████| 56/56 [00:00<00:00, 113414.30it/s]
# autoanchor: Evolving anchors with Genetic Algorithm::   0%|          | 0/1000 [00:00<?, ?it/s]
# autoanchor: Running kmeans for 9 anchors on 56 points...
# autoanchor: thr=0.25: 1.0000 best possible recall, 9.00 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.728/0.968-mean/best, past_thr=0.728-mean: 24,60,  22,64,  27,64,  27,72,  29,78,  35,92,  53,71,  44,98,  43,111
# autoanchor: thr=0.25: 1.0000 best possible recall, 9.00 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.728/0.968-mean/best, past_thr=0.728-mean: 24,60,  22,65,  28,64,  27,72,  29,78,  35,92,  54,71,  44,98,  43,111
# autoanchor: Evolving anchors with Genetic Algorithm: fitness = 0.9685: 100%|██████████| 1000/1000 [00:00<00:00, 4034.80it/s]
# autoanchor: thr=0.25: 1.0000 best possible recall, 9.00 anchors past thr
# ...
